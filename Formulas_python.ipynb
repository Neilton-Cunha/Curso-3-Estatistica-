# %% [markdown]
# <a href="https://colab.research.google.com/github/Neilton-Cunha/Curso-3-Estatistica-/blob/main/Formulas_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===== COLA - PANDAS (ESTATÍSTICA DESCRITIVA) =====

# Estatísticas
elemento.count()               # Conta valores não nulos.
elemento.mean()                # Média.
elemento.median()              # Mediana.
elemento.mode()                # Moda.
elemento.min()                 # Menor valor.
elemento.max()                 # Maior valor.
elemento.sum()                 # Soma.
elemento.std()                 # Desvio padrão.
elemento.var()                 # Variância.
elemento.quantile(0.25)        # Quantil.
elemento.describe()            # Resumo estatístico.

# Frequências
elemento.value_counts()                     # Frequência absoluta.
elemento.value_counts(normalize=True)       # Frequência relativa.
elemento.unique()                           # Valores únicos.
elemento.nunique()                          # Quantidade de valores únicos.

# Distribuição
pd.cut(elemento, bins=5)                    # Divide em classes.
pd.cut(elemento, bins=5).value_counts()     # Frequência por classe.

# Ordenação
elemento.sort_values()                      # Ordena pelos valores.
elemento.sort_index()                       # Ordena pelo índice.

# Agrupamento
df.groupby('Coluna').mean()                 # Média por grupo.

# Dados ausentes
df.isnull().sum()                           # Conta valores nulos.
df.dropna()                                 # Remove valores nulos.

# Outros
df.query('condição')          # Filtra linhas que atendem a uma condição.
df.loc[linhas, colunas]    # Seleciona linhas e colunas pelos rótulos (labels).
df.sample()               # Retorna uma amostra aleatória do DataFrame.
df.abs()                     # Retorna o valor absoluto (remove o sinal negativo).
